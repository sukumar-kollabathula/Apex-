# %% [markdown]
# <a href="https://colab.research.google.com/github/sukumar-kollabathula/Apex-/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# TASK-1 : DATA IMMERSION & WRANGLING
# !pip install pandas numpy matplotlib seaborn missingno openpyxl -q

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4a327c65-8906-46d2-8989-ad3204b46737" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4a327c65-8906-46d2-8989-ad3204b46737">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Extract the content of the zip file
# !unzip -o archive.zip

# Load the 'Customer_Data.csv' file from the extracted content
df = pd.read_csv('Customer_Data.csv')
# Out:
# Archive:  archive.zip
#   inflating: Customer_Data.csv

# %%
# First 5 rows
df.head()
# Shape of dataset
print("Rows and Columns:", df.shape)
# Column names
print(df.columns)
# Dataset information
df.info()
# Statistical summary
df.describe()
# Out:
# Rows and Columns: (8950, 18)
# Index(['cust_id', 'balance', 'balance_frequency', 'purchases',
#        'oneoff_purchases', 'installments_purchases', 'cash_advance',
#        'purchases_frequency', 'oneoff_purchases_frequency',
#        'purchases_installments_frequency', 'cash_advance_frequency',
#        'cash_advance_trx', 'purchases_trx', 'credit_limit', 'payments',
#        'minimum_payments', 'prc_full_payment', 'tenure'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   cust_id                           8950 non-null   object
#  1   balance                           8950 non-null   float64
#  2   balance_frequency                 8950 non-null   float64
#  3   purchases                         8950 non-null   float64
# ...

# %%
data_dictionary = pd.DataFrame({
    'Column Name': df.columns,
    'Data Type': df.dtypes.values,
    'Missing Values': df.isnull().sum().values
})

data_dictionary
# Out:
#                          Column Name Data Type  Missing Values
# 0                            cust_id    object               0
# 1                            balance   float64               0
# 2                  balance_frequency   float64               0
# 3                          purchases   float64               0
# 4                   oneoff_purchases   float64               0
# 5             installments_purchases   float64               0
# 6                       cash_advance   float64               0
# 7                purchases_frequency   float64               0
# 8         oneoff_purchases_frequency   float64               0
# 9   purchases_installments_frequency   float64               0
# 10            cash_advance_frequency   float64               0
# 11                  cash_advance_trx     int64               0
# 12                     purchases_trx     int64               0
# 13                      credit_limit   float64               1
# ...

# %%
data_dictionary.to_csv("data_dictionary.csv", index=False)

# %%
# Count missing values
missing_values = df.isnull().sum()

print(missing_values)
# Out:
# cust_id                               0
# balance                               0
# balance_frequency                     0
# purchases                             0
# oneoff_purchases                      0
# installments_purchases                0
# cash_advance                          0
# purchases_frequency                   0
# oneoff_purchases_frequency            0
# purchases_installments_frequency      0
# cash_advance_frequency                0
# cash_advance_trx                      0
# purchases_trx                         0
# credit_limit                          1
# payments                              0
# minimum_payments                    313
# prc_full_payment                      0
# tenure                                0
# dtype: int64

# %%
msno.matrix(df)
plt.show()

# %%
# Example: convert column names to lowercase

df.columns = df.columns.str.lower().str.strip()

df.columns
# Out:
# Index(['cust_id', 'balance', 'balance_frequency', 'purchases',
#        'oneoff_purchases', 'installments_purchases', 'cash_advance',
#        'purchases_frequency', 'oneoff_purchases_frequency',
#        'purchases_installments_frequency', 'cash_advance_frequency',
#        'cash_advance_trx', 'purchases_trx', 'credit_limit', 'payments',
#        'minimum_payments', 'prc_full_payment', 'tenure'],
#       dtype='object')

# %%
# Remove extra spaces in string columns

for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].str.strip()

# %%
duplicates = df.duplicated().sum()

print("Duplicate Rows:", duplicates)
# Out:
# Duplicate Rows: 0

# %%
df = df.drop_duplicates()

# %%
num_cols = df.select_dtypes(include=np.number).columns

for col in num_cols:
    df[col].fillna(df[col].median(), inplace=True)
# Out:
# /tmp/ipykernel_14422/3551297251.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)

# %%
cat_cols = df.select_dtypes(include='object').columns

for col in cat_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_14422/2422164989.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df[num_cols])
plt.xticks(rotation=90)
plt.show()

# %%
for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    df = df[(df[col] >= lower) & (df[col] <= upper)]

# %%
# The original dataset does not contain an 'order_date' column.
# If you have a different column representing dates, please replace 'order_date' with its actual name.
# Example if you had a 'transaction_date' column:
# df['transaction_date'] = pd.to_datetime(df['transaction_date'])
# df['year'] = df['transaction_date'].dt.year
# df['month'] = df['transaction_date'].dt.month
# df['day'] = df['transaction_date'].dt.day

# %%
# Example DOB column
# df['date_of_birth'] = pd.to_datetime(df['date_of_birth'])

# current_year = pd.Timestamp.now().year

# df['customer_age'] = current_year - df['date_of_birth'].dt.year

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
df.head()
# Out:
#         balance  balance_frequency  purchases  oneoff_purchases  \
# 0     40.900749           0.818182      95.40              0.00
# 4    817.714335           1.000000      16.00             16.00
# 7   1823.652743           1.000000     436.20              0.00
# 8   1014.926473           1.000000     861.49            661.49
# 14  2772.772734           1.000000       0.00              0.00
#
#     installments_purchases  cash_advance  purchases_frequency  \
# 0                     95.4       0.00000             0.166667
# 4                      0.0       0.00000             0.083333
# 7                    436.2       0.00000             1.000000
# 8                    200.0       0.00000             0.333333
# 14                     0.0     346.81139             0.000000
#
#     oneoff_purchases_frequency  purchases_installments_frequency  \
# 0                     0.000000                          0.083333
# 4                     0.083333                          0.000000
# ...

# %%
df.to_csv("cleaned_dataset.csv", index=False)

# %%
files.download("cleaned_dataset.csv")
